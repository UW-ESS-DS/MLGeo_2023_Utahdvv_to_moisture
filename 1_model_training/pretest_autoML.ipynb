# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pycaret

# %% [markdown]
# ## Data Preparation

# %%
# Read in data and display first 5 rows
fn='../Data/INTERP_BGU.csv'
features = pd.read_csv(fn)
features.head()
# Out:
#          utvec      dv     err     temp    SM_EWT        date
# 0  2007.089722 -0.1144  0.1078 -1.94899  0.464541  2007-02-03
# 1  2007.092407 -0.1211  0.1080 -1.92494  0.464670  2007-02-04
# 2  2007.095093 -0.1260  0.1080 -1.82530  0.464805  2007-02-05
# 3  2007.097900 -0.1276  0.1075 -1.57670  0.464934  2007-02-06
# 4  2007.100586 -0.1357  0.1084 -1.36909  0.465069  2007-02-07

# %%
data_day=features.utvec
data_date=features.date
features=features.drop(columns=['utvec','date','err'])
features.head()
# Out:
#        dv     temp    SM_EWT
# 0 -0.1144 -1.94899  0.464541
# 1 -0.1211 -1.92494  0.464670
# 2 -0.1260 -1.82530  0.464805
# 3 -0.1276 -1.57670  0.464934
# 4 -0.1357 -1.36909  0.465069

# %%
# Descriptive statistics for each column
features.describe()
# Out:
#                 dv         temp       SM_EWT
# count  5675.000000  5675.000000  5675.000000
# mean      0.004079    10.225376     0.460619
# std       0.205298     8.896228     0.025127
# min      -0.423000    -5.268270     0.415005
# 25%      -0.152600     2.133070     0.446141
# 50%       0.000799     9.196760     0.456210
# 75%       0.155100    18.705700     0.470845
# max       0.472300    25.834000     0.546989

# %%
features.temp=features.temp-np.mean(features.temp)
features.SM_EWT=features.SM_EWT-np.mean(features.SM_EWT)

# %%
features.dv=features.dv/np.max(np.abs(features.dv))
features.temp=features.temp/np.max(np.abs(features.temp))
features.SM_EWT=features.SM_EWT/np.max(np.abs(features.SM_EWT))

# %%
train_ratio=0.1
total_num=len(features)
train_set= int(train_ratio*total_num) 
test_set= total_num - train_set

# %%
train_df = features[ :train_set]
test_df = features[train_set: ]
print('Data for Modeling: ' + str(train_df.shape))
print('Unseen Data For Predictions: ' + str(test_df.shape))
# Out:
# Data for Modeling: (567, 3)
# Unseen Data For Predictions: (5108, 3)

# %%
#!pip install Scikit-learn==1.1
#!pip install scikit-plot

# %%
from pycaret.regression import *
exp_reg101 = setup(data = train_df, 
                   target = 'SM_EWT',
                   #mputation_type='iterative', 
                   fold_shuffle=True, 
                   session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b95b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b95b3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b95b3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b95b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b95b3_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b95b3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b95b3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b95b3_row1_col1" class="data row1 col1" >SM_EWT</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b95b3_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_b95b3_row2_col1" class="data row2 col1" >(567, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b95b3_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_b95b3_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b95b3_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_b95b3_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b95b3_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_b95b3_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b95b3_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_b95b3_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b95b3_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_b95b3_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b95b3_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_b95b3_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b95b3_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_b95b3_row9_col1" class="data row9 col1" >(396, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b95b3_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_b95b3_row10_col1" class="data row10 col1" >(171, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b95b3_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_b95b3_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b95b3_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_b95b3_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b95b3_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_b95b3_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b95b3_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_b95b3_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b95b3_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_b95b3_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b95b3_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_b95b3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b95b3_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_b95b3_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b95b3_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_b95b3_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b95b3_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_b95b3_row19_col1" class="data row19 col1" >5f30</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b95b3_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_b95b3_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b95b3_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b95b3_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b95b3_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_b95b3_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b95b3_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b95b3_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b95b3_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_b95b3_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b95b3_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b95b3_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b95b3_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b95b3_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b95b3_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_b95b3_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b95b3_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_b95b3_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b95b3_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_b95b3_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b95b3_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b95b3_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_b95b3_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 from pycaret.regression import *
# ----> 2 exp_reg101 = setup(data = train_df,
#       3                    target = 'SM_EWT',
#       4                    #mputation_type='iterative',
#       5                    fold_shuffle=True,
#       6                    session_id=123)
#
# File ~/miniconda3/lib/python3.10/site-packages/pycaret/regression.py:571, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     568 if log_plots == True:
#     569     log_plots = ["residuals", "error", "feature"]
# --> 571 return pycaret.internal.tabular.setup(
#     572     ml_usecase="regression",
#     573     available_plots=available_plots,
#     574     data=data,
#     575     target=target,
#     576     train_size=train_size,
#     577     test_data=test_data,
#     578     preprocess=preprocess,
#     579     imputation_type=imputation_type,
#     580     iterative_imputation_iters=iterative_imputation_iters,
#     581     categorical_features=categorical_features,
#     582     categorical_imputation=categorical_imputation,
#     583     categorical_iterative_imputer=categorical_iterative_imputer,
#     584     ordinal_features=ordinal_features,
#     585     high_cardinality_features=high_cardinality_features,
#     586     high_cardinality_method=high_cardinality_method,
#     587     numeric_features=numeric_features,
#     588     numeric_imputation=numeric_imputation,
#     589     numeric_iterative_imputer=numeric_iterative_imputer,
#     590     date_features=date_features,
#     591     ignore_features=ignore_features,
#     592     normalize=normalize,
#     593     normalize_method=normalize_method,
#     594     transformation=transformation,
#     595     transformation_method=transformation_method,
#     596     handle_unknown_categorical=handle_unknown_categorical,
#     597     unknown_categorical_method=unknown_categorical_method,
#     598     pca=pca,
#     599     pca_method=pca_method,
#     600     pca_components=pca_components,
#     601     ignore_low_variance=ignore_low_variance,
#     602     combine_rare_levels=combine_rare_levels,
#     603     rare_level_threshold=rare_level_threshold,
#     604     bin_numeric_features=bin_numeric_features,
#     605     remove_outliers=remove_outliers,
#     606     outliers_threshold=outliers_threshold,
#     607     remove_multicollinearity=remove_multicollinearity,
#     608     multicollinearity_threshold=multicollinearity_threshold,
#     609     remove_perfect_collinearity=remove_perfect_collinearity,
#     610     create_clusters=create_clusters,
#     611     cluster_iter=cluster_iter,
#     612     polynomial_features=polynomial_features,
#     613     polynomial_degree=polynomial_degree,
#     614     trigonometry_features=trigonometry_features,
#     615     polynomial_threshold=polynomial_threshold,
#     616     group_features=group_features,
#     617     group_names=group_names,
#     618     feature_selection=feature_selection,
#     619     feature_selection_threshold=feature_selection_threshold,
#     620     feature_selection_method=feature_selection_method,
#     621     feature_interaction=feature_interaction,
#     622     feature_ratio=feature_ratio,
#     623     interaction_threshold=interaction_threshold,
#     624     transform_target=transform_target,
#     625     transform_target_method=transform_target_method,
#     626     data_split_shuffle=data_split_shuffle,
#     627     data_split_stratify=data_split_stratify,
#     628     fold_strategy=fold_strategy,
#     629     fold=fold,
#     630     fold_shuffle=fold_shuffle,
#     631     fold_groups=fold_groups,
#     632     n_jobs=n_jobs,
#     633     use_gpu=use_gpu,
#     634     custom_pipeline=custom_pipeline,
#     635     html=html,
#     636     session_id=session_id,
#     637     log_experiment=log_experiment,
#     638     experiment_name=experiment_name,
#     639     log_plots=log_plots,
#     640     log_profile=log_profile,
#     641     log_data=log_data,
#     642     silent=silent,
#     643     verbose=verbose,
#     644     profile=profile,
#     645     profile_kwargs=profile_kwargs,
#     646 )
#
# File ~/miniconda3/lib/python3.10/site-packages/pycaret/internal/tabular.py:1750, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1747 logger.info(f"master_model_container: {len(master_model_container)}")
#    1748 logger.info(f"display_container: {len(display_container)}")
# -> 1750 logger.info(str(prep_pipe))
#    1751 logger.info("setup() succesfully completed......................................")
#    1753 gc.collect()
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File ~/miniconda3/lib/python3.10/pprint.py:157, in PrettyPrinter.pformat(self, object)
#     155 def pformat(self, object):
#     156     sio = _StringIO()
# --> 157     self._format(object, sio, 0, 0, {}, 0)
#     158     return sio.getvalue()
#
# File ~/miniconda3/lib/python3.10/pprint.py:174, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     172     self._readable = False
#     173     return
# --> 174 rep = self._repr(object, context, level)
#     175 max_width = self._width - indent - allowance
#     176 if len(rep) > max_width:
#
# File ~/miniconda3/lib/python3.10/pprint.py:454, in PrettyPrinter._repr(self, object, context, level)
#     453 def _repr(self, object, context, level):
# --> 454     repr, readable, recursive = self.format(object, context.copy(),
#     455                                             self._depth, level)
#     456     if not readable:
#     457         self._readable = False
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/utils/_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/utils/_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/utils/_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/utils/_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/utils/_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File ~/miniconda3/lib/python3.10/site-packages/sklearn/base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params"):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
plt.plot(train_df, 'b-')
#plt.plot(np.arange(train_set), train_set, 'r*')
plt.title("Training Data")
plt.grid(True)
#plt.subplot(1,3,2)
#plt.plot(x_val, 'b-')
#plt.title("Validation Data")
#plt.grid(True)
#plt.subplot(1,3,3)
#plt.plot(test_df, 'b-')
#plt.title("Test Data")

plt.grid(True)
